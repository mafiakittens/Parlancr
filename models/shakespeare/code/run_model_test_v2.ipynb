# %%
import sys
sys.executable
# Out:
# '/home/chadharness/anaconda3/envs/tensorflow/bin/python'

# %%
# !pwd
# Out:
# /home/chadharness/w210/language-style-transfer-test-v2/language-style-transfer/code

# %%
# !python style_transfer.py --train ../data/yelp/shakes_mod.train --dev ../data/yelp/shakes_mod.valid --output ../tmp/shakes_mod.valid --vocab ../tmp/shakes_mod.vocab --model ../tmp/model --max_epochs 42 --max_seq_length 156
# Out:
# ------------------------------------------------
# {   'batch_size': 64,
#     'beam': 1,
#     'dev': '../data/yelp/shakes_mod.valid',
#     'dim_emb': 100,
#     'dim_y': 200,
#     'dim_z': 500,
#     'dropout_keep_prob': 0.5,
#     'embedding': '',
#     'filter_sizes': '1,2,3,4,5',
#     'gamma_decay': 1,
#     'gamma_init': 0.1,
#     'gamma_min': 0.1,
#     'learning_rate': 0.0005,
#     'load_model': False,
#     'max_epochs': 42,
#     'max_seq_length': 156,
#     'max_train_size': -1,
#     'model': '../tmp/model',
#     'n_filters': 128,
#     'n_layers': 1,
#     'online_testing': False,
#     'output': '../tmp/shakes_mod.valid',
#     'rho': 1,
#     'steps_per_checkpoint': 1000,
#     'test': '',
#     'train': '../data/yelp/shakes_mod.train',
#     'vocab': '../tmp/shakes_mod.vocab'}
# ------------------------------------------------
# #sents of training file 0: 18395
# #sents of training file 1: 18395
# vocabulary size: 4486
# ...

# %%
# !python style_transfer.py --test ../data/yelp/shakes_mod.test --output ../tmp/shakes_mod.test --vocab ../tmp/shakes_mod.vocab --model ../tmp/model --load_model true --beam 8
# Out:
# ------------------------------------------------
# {   'batch_size': 64,
#     'beam': 8,
#     'dev': '',
#     'dim_emb': 100,
#     'dim_y': 200,
#     'dim_z': 500,
#     'dropout_keep_prob': 0.5,
#     'embedding': '',
#     'filter_sizes': '1,2,3,4,5',
#     'gamma_decay': 1,
#     'gamma_init': 0.1,
#     'gamma_min': 0.1,
#     'learning_rate': 0.0005,
#     'load_model': True,
#     'max_epochs': 20,
#     'max_seq_length': 20,
#     'max_train_size': -1,
#     'model': '../tmp/model',
#     'n_filters': 128,
#     'n_layers': 1,
#     'online_testing': False,
#     'output': '../tmp/shakes_mod.test',
#     'rho': 1,
#     'steps_per_checkpoint': 1000,
#     'test': '../data/yelp/shakes_mod.test',
#     'train': '',
#     'vocab': '../tmp/shakes_mod.vocab'}
# ------------------------------------------------
# vocabulary size: 4486
# ...
