# %%
import sys
sys.executable
# Out:
# '/home/chadharness/anaconda3/envs/tensorflow/bin/python'

# %%
# !pwd
# Out:
# /home/chadharness/w210/language-style-transfer-test-v1/language-style-transfer/code

# %%
# !python style_transfer.py --train ../data/yelp/reddit_thedonald.train --dev ../data/yelp/reddit_thedonald.dev --output ../tmp/reddit_thedonald.dev --vocab ../tmp/reddit_thedonald.vocab --model ../tmp/model
# Out:
# ------------------------------------------------
# {   'batch_size': 64,
#     'beam': 1,
#     'dev': '../data/yelp/reddit_thedonald.dev',
#     'dim_emb': 100,
#     'dim_y': 200,
#     'dim_z': 500,
#     'dropout_keep_prob': 0.5,
#     'embedding': '',
#     'filter_sizes': '1,2,3,4,5',
#     'gamma_decay': 1,
#     'gamma_init': 0.1,
#     'gamma_min': 0.1,
#     'learning_rate': 0.0005,
#     'load_model': False,
#     'max_epochs': 20,
#     'max_seq_length': 20,
#     'max_train_size': -1,
#     'model': '../tmp/model',
#     'n_filters': 128,
#     'n_layers': 1,
#     'online_testing': False,
#     'output': '../tmp/reddit_thedonald.dev',
#     'rho': 1,
#     'steps_per_checkpoint': 1000,
#     'test': '',
#     'train': '../data/yelp/reddit_thedonald.train',
#     'vocab': '../tmp/reddit_thedonald.vocab'}
# ------------------------------------------------
# #sents of training file 0: 175306
# #sents of training file 1: 266445
# vocabulary size: 39272
# ...

# %%
# !python style_transfer.py --test ../data/yelp/reddit_thedonald.test --output ../tmp/reddit_thedonald.test --vocab ../tmp/reddit_thedonald.vocab --model ../tmp/model --load_model true --beam 8
# Out:
# ------------------------------------------------
# {   'batch_size': 64,
#     'beam': 8,
#     'dev': '',
#     'dim_emb': 100,
#     'dim_y': 200,
#     'dim_z': 500,
#     'dropout_keep_prob': 0.5,
#     'embedding': '',
#     'filter_sizes': '1,2,3,4,5',
#     'gamma_decay': 1,
#     'gamma_init': 0.1,
#     'gamma_min': 0.1,
#     'learning_rate': 0.0005,
#     'load_model': True,
#     'max_epochs': 20,
#     'max_seq_length': 20,
#     'max_train_size': -1,
#     'model': '../tmp/model',
#     'n_filters': 128,
#     'n_layers': 1,
#     'online_testing': False,
#     'output': '../tmp/reddit_thedonald.test',
#     'rho': 1,
#     'steps_per_checkpoint': 1000,
#     'test': '../data/yelp/reddit_thedonald.test',
#     'train': '',
#     'vocab': '../tmp/reddit_thedonald.vocab'}
# ------------------------------------------------
# vocabulary size: 39272
# ...
