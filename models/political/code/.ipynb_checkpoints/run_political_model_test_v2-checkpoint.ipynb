# %%
import sys
sys.executable
# Out:
# '/home/alexander_mpa/anaconda3/envs/py27/bin/python'

# %%
# !python style_transfer.py --train ../data/political.train --dev ../data/political.test --output ../tmp/political.valid --vocab ../tmp/political.vocab --model ../tmp/model --max_epochs 40 --max_seq_length 25
# Out:
# /home/alexander_mpa/anaconda3/envs/py27/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# ------------------------------------------------
# {   'batch_size': 64,
#     'beam': 1,
#     'dev': '../data/political.test',
#     'dim_emb': 100,
#     'dim_y': 200,
#     'dim_z': 500,
#     'dropout_keep_prob': 0.5,
#     'embedding': '',
#     'filter_sizes': '1,2,3,4,5',
#     'gamma_decay': 1,
#     'gamma_init': 0.1,
#     'gamma_min': 0.1,
#     'learning_rate': 0.0005,
#     'load_model': False,
#     'max_epochs': 40,
#     'max_seq_length': 25,
#     'max_train_size': -1,
#     'model': '../tmp/model',
#     'n_filters': 128,
#     'n_layers': 1,
#     'online_testing': False,
#     'output': '../tmp/political.valid',
#     'rho': 1,
# ...

# %%
# !python style_transfer.py --test ../data/simple.test --output ../tmp/simple.test --vocab ../tmp/political.vocab --model ../tmp/model --load_model true --beam 8
# Out:
# /home/alexander_mpa/anaconda3/envs/py27/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# ------------------------------------------------
# {   'batch_size': 64,
#     'beam': 8,
#     'dev': '',
#     'dim_emb': 100,
#     'dim_y': 200,
#     'dim_z': 500,
#     'dropout_keep_prob': 0.5,
#     'embedding': '',
#     'filter_sizes': '1,2,3,4,5',
#     'gamma_decay': 1,
#     'gamma_init': 0.1,
#     'gamma_min': 0.1,
#     'learning_rate': 0.0005,
#     'load_model': True,
#     'max_epochs': 20,
#     'max_seq_length': 25,
#     'max_train_size': -1,
#     'model': '../tmp/model',
#     'n_filters': 128,
#     'n_layers': 1,
#     'online_testing': False,
#     'output': '../tmp/political.dev',
#     'rho': 1,
# ...
